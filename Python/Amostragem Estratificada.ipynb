# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
iris = pd.read_csv("iris.csv")
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
iris["class"].value_counts() # Contar repetidos
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: class, dtype: int64

# %%
x, _, y, _ = train_test_split(iris.iloc[:,0:4], iris.iloc[:,4], test_size=0.5, stratify=iris.iloc[:,4])

# %%
x
# Out:
#      sepal length  sepal width  petal length  petal width
# 28            5.2          3.4           1.4          0.2
# 5             5.4          3.9           1.7          0.4
# 12            4.8          3.0           1.4          0.1
# 99            5.7          2.8           4.1          1.3
# 129           7.2          3.0           5.8          1.6
# 59            5.2          2.7           3.9          1.4
# 139           6.9          3.1           5.4          2.1
# 140           6.7          3.1           5.6          2.4
# 61            5.9          3.0           4.2          1.5
# 110           6.5          3.2           5.1          2.0
# 1             4.9          3.0           1.4          0.2
# 92            5.8          2.6           4.0          1.2
# 112           6.8          3.0           5.5          2.1
# 71            6.1          2.8           4.0          1.3
# 60            5.0          2.0           3.5          1.0
# ...

# %%
y
# Out:
# 28         Iris-setosa
# 5          Iris-setosa
# 12         Iris-setosa
# 99     Iris-versicolor
# 129     Iris-virginica
# 59     Iris-versicolor
# 139     Iris-virginica
# 140     Iris-virginica
# 61     Iris-versicolor
# 110     Iris-virginica
# 1          Iris-setosa
# 92     Iris-versicolor
# 112     Iris-virginica
# 71     Iris-versicolor
# 60     Iris-versicolor
# 4          Iris-setosa
# 132     Iris-virginica
# 55     Iris-versicolor
# 7          Iris-setosa
# 90     Iris-versicolor
# 23         Iris-setosa
# 22         Iris-setosa
# 127     Iris-virginica
# 96     Iris-versicolor
# 39         Iris-setosa
# 15         Iris-setosa
# 116     Iris-virginica
# 103     Iris-virginica
# 72     Iris-versicolor
# 142     Iris-virginica
#             ...
# 149     Iris-virginica
# 104     Iris-virginica
# 79     Iris-versicolor
# 32         Iris-setosa
# 101     Iris-virginica
# 31         Iris-setosa
# 119     Iris-virginica
# 91     Iris-versicolor
# 86     Iris-versicolor
# ...

# %%
x.shape
# Out:
# (75, 4)

# %%
y.shape
# Out:
# (75,)

# %%
y.value_counts()
# Out:
# Iris-setosa        25
# Iris-virginica     25
# Iris-versicolor    25
# Name: class, dtype: int64

# %%
infert =pd.read_csv("infert.csv")
infert
# Out:
#      Unnamed: 0 education  age  parity  induced  case  spontaneous  stratum  \
# 0             1    0-5yrs   26       6        1     1            2        1
# 1             2    0-5yrs   42       1        1     1            0        2
# 2             3    0-5yrs   39       6        2     1            0        3
# 3             4    0-5yrs   34       4        2     1            0        4
# 4             5   6-11yrs   35       3        1     1            1        5
# 5             6   6-11yrs   36       4        2     1            1        6
# 6             7   6-11yrs   23       1        0     1            0        7
# 7             8   6-11yrs   32       2        0     1            0        8
# 8             9   6-11yrs   21       1        0     1            1        9
# 9            10   6-11yrs   28       2        0     1            0       10
# 10           11   6-11yrs   29       2        1     1            0       11
# ...

# %%
infert["education"].value_counts().sort_index() # Ordenar crescente
# Out:
# 0-5yrs      12
# 12+ yrs    116
# 6-11yrs    120
# Name: education, dtype: int64

# %%
x1, _, y1, _ = train_test_split(infert.iloc[:,2:9], infert.iloc[:,1], test_size=0.6, stratify=infert.iloc[:,1], random_state=1996)

# %%
y1.value_counts(sort=True, ascending=True) # Ordenar
# Out:
# 0-5yrs      5
# 12+ yrs    46
# 6-11yrs    48
# Name: education, dtype: int64
