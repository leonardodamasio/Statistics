# %%
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
dados = norm.rvs(size=100) # rvs = Random variates | Gerar dados em uma distribuição normal
dados
# Out:
# array([-0.0200003 ,  0.80051436,  0.83095076,  1.90578273, -0.94167256,
#         0.025338  ,  0.94690566, -0.29666491, -0.13291949,  1.08885545,
#         0.79250139,  0.06478326, -0.29701095, -1.90122542,  0.50114707,
#        -1.02079447, -0.49885483,  0.57346258, -0.06516169, -0.80076883,
#        -1.21640542, -1.46682445,  1.95836347,  0.18476171, -1.86993299,
#         0.28823299, -0.48229593, -0.16026109,  0.7390016 , -0.9525761 ,
#        -0.62906819,  1.43772537, -1.51145334,  2.53178343,  0.81350142,
#        -0.42267481,  0.17334053,  1.87163476, -1.00759316,  1.59205283,
#        -1.65832468,  0.71926185, -0.47727214, -0.57372936,  0.78719506,
#        -0.26885688,  0.91682224,  0.89628119, -0.20731298,  0.43690995,
#        -0.92597541,  0.09907388, -1.38898989, -0.0084286 , -0.1806437 ,
#        -0.5473624 , -0.52250789,  1.38077133, -1.79617159, -0.2300137 ,
#        -1.01639831,  0.85526255, -0.52395062,  0.21381499, -0.32199639,
# ...

# %%
stats.probplot(dados, plot=plt)
# Out:
# ((array([-2.46203784, -2.12570747, -1.93122778, -1.79044653, -1.67819304,
#          -1.58381122, -1.50174123, -1.42869743, -1.36256869, -1.30191411,
#          -1.24570419, -1.19317644, -1.14374949, -1.09696931, -1.05247413,
#          -1.00997067, -0.96921765, -0.93001393, -0.89218993, -0.85560121,
#          -0.82012357, -0.78564937, -0.75208458, -0.71934648, -0.68736185,
#          -0.65606548, -0.62539893, -0.59530962, -0.56574992, -0.53667655,
#          -0.50804994, -0.47983378, -0.45199463, -0.42450149, -0.39732558,
#          -0.37044003, -0.34381966, -0.31744076, -0.29128096, -0.26531902,
#          -0.23953472, -0.21390872, -0.18842244, -0.16305799, -0.13779803,
#          -0.1126257 , -0.08752455, -0.06247843, -0.03747145, -0.01248789,
#           0.01248789,  0.03747145,  0.06247843,  0.08752455,  0.1126257 ,
#           0.13779803,  0.16305799,  0.18842244,  0.21390872,  0.23953472,
#           0.26531902,  0.29128096,  0.31744076,  0.34381966,  0.37044003,
# ...

# %%
stats.shapiro(dados) # Teste de Shapiro-Wilk
# Out:
# (0.9913382530212402, 0.7714849710464478)
